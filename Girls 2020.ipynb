# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
girls_arrested = pd.read_csv('Girls arrested 2020.csv')
girls_arrested.head()
# Out:
#   Fiscal Year  Slicer  COVID FILTER  Data Slicer  Location  Offenses  \
# 0  FY 2019-20  Female          True         True      True      True
# 1  FY 2019-20  Female          True         True      True      True
# 2  FY 2019-20  Female          True         True      True      True
# 3  FY 2019-20  Female          True         True      True      True
# 4  FY 2019-20  Female          True         True      True      True
#
#   Select Sheet  Stage Filter         AGE   AGE1  ...    Stage Stages1 Arrests  \
# 0           S1          True  Age 13 - 14  14.0  ...  Arrests  Intake     1.0
# 1           S1          True      Age 17+  17.0  ...  Arrests  Intake     1.0
# 2           S1          True  Age 13 - 14  14.0  ...  Arrests  Intake     1.0
# 3           S1          True  Age 13 - 14  13.0  ...  Arrests  Intake     1.0
# 4           S1          True  Age 15 - 16  15.0  ...  Arrests  Intake     1.0
#
#   Arrests per 1000 Arrests/Youth  Arrests/Youth  Youth Youth per 1000  \
# ...
