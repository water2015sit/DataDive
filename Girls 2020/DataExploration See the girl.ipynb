# %% [markdown]
# # Data Exploration Task

# %% [markdown]
# - The Policy Center is eager to explore the potential of analytics and to see the possibilities that data science might offer in creating an understanding of the status of girls in Florida and the need for recommended action. This workstream is intended to be exploratory and to demonstrate the possibility (or lack thereof) of deriving additional insights as to the long-term outcomes for girls, young women, and youth who identify as female.
#
# - Datasets that might be of interest to compare with outcomes in the sample datasets include: ACS (census) data, COVID-19 cases, data from the City of Orlando’s Open Data Portal (and other city or county data portals), public health data, county-level employment/unemployment data, housing loss, Stanford School Enrollment Project, USDA ERS resource (county level poverty, population, unemployment, education), among others.
#
# - Example data exploration papers that might be helpful as starting points:
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7456591/
# https://www.ojp.gov/pdffiles1/ojjdp/226358.pdf
# https://www.equalmeasure.org/wp-content/uploads/2019/12/EquityCounts_OYF-Measures-Brief_EqM_FINAL_Oct19.pdf
# https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2720072
# - Exploration question ideas
# - The Policy Center is actively looking to improve the lives of girls, particularly those who have interactions with the justice system, so it might be interesting to understand if there are relationships between arrest or discipline outcomes and any socioeconomic, health, demographic or other variables
# - The Policy Center is interested in understanding outcomes for girls, it might be interesting to look at if outcomes cluster together - e.g. do counties that have higher arrest rates also have higher school discipline rates?
# - Deep dives into particular geographies

# %%
# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)

import warnings

warnings.filterwarnings("ignore")
from statsmodels.tools.sm_exceptions import ConvergenceWarning

warnings.simplefilter("ignore", ConvergenceWarning)
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
# read student by race file
stbyrace = pd.read_excel("StudentsbyRace.xlsx")

# %%
stbyrace.shape
# Out:
# (77, 36)

# %%
stbyrace
# Out:
#          Unnamed: 0 % of Students by Race % of Students by Race.1  \
# 0    Race/Ethnicity               1-White                 1-White
# 1              Year               2015-16                 2016-17
# 2          District                   NaN                     NaN
# 3        01-ALACHUA              0.436747                  0.4313
# 4          02-BAKER              0.824033                  0.8249
# ..              ...                   ...                     ...
# 72    71-FL VIRTUAL              0.594609                0.591045
# 73   72-FAU LAB SCH                0.4148                0.423969
# 74   73-FSU LAB SCH              0.419154                0.419784
# 75  74-FAMU LAB SCH                  **.*                    **.*
# 76    75-UF LAB SCH              0.497382                0.486063
#
#    % of Students by Race.2 % of Students by Race.3 % of Students by Race.4  \
# 0                  1-White                 1-White                 1-White
# ...

# %%
# read girls arrested 2020 file
girlsarst2020 = pd.read_excel("Girlsarrested2020.xlsx")

# %%
girlsarst2020
# Out:
#        FiscalYear  Slicer  COVIDFILTER  DataSlicer  Location  Offenses  \
# 0      FY 2019-20  Female         True        True      True      True
# 1      FY 2019-20  Female         True        True      True      True
# 2      FY 2019-20  Female         True        True      True      True
# 3      FY 2019-20  Female         True        True      True      True
# 4      FY 2019-20  Female         True        True      True      True
# ...           ...     ...          ...         ...       ...       ...
# 10604  FY 2019-20  Female         True        True      True      True
# 10605  FY 2019-20  Female         True        True      True      True
# 10606  FY 2019-20  Female         True        True      True      True
# 10607  FY 2019-20  Female         True        True      True      True
# 10608  FY 2019-20  Female         True        True      True      True
#
#       SelectSheet  StageFilter          AGE  AGE1  All BasicRaceSexEthnicity  \
# ...

# %%
girlsarst2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10609 entries, 0 to 10608
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FiscalYear             10609 non-null  object
#  1   Slicer                 10609 non-null  object
#  2   COVIDFILTER            10609 non-null  bool
#  3   DataSlicer             10609 non-null  bool
#  4   Location               10609 non-null  bool
#  5   Offenses               10609 non-null  bool
#  6   SelectSheet            10609 non-null  object
#  7   StageFilter            10609 non-null  bool
#  8   AGE                    10609 non-null  object
#  9   AGE1                   10539 non-null  float64
#  10  All                    10609 non-null  object
#  11  BasicRaceSexEthnicity  10609 non-null  object
#  12  Category1              10539 non-null  object
#  13  Circuit1               10608 non-null  object
# ...

# %%
girlsarst2020.columns
# Out:
# Index(['Fiscal Year', 'Slicer', 'COVID FILTER', 'Data Slicer', 'Location',
#        'Offenses', 'Select Sheet', 'Stage Filter', 'AGE ', 'AGE1', 'All',
#        'Basic Race Sex Ethnicity', 'Category1', 'Circuit1', 'County   ',
#        'COVIDMONTHS', 'Date', 'Ethnic Group', 'Gender1', 'Offense1', 'Region',
#        'Stage', 'Stages1', 'Arrests', 'Arrests per 1000', 'Arrests/Youth',
#        'Arrests/Youth ', 'Youth', 'Youth per 1000', 'Youth Population',
#        'Youthpop'],
#       dtype='object')

# %%
girlsarst2020.columns = girlsarst2020.columns.str.replace(" ", "")

# %%
girlsarst2020.columns
# Out:
# Index(['FiscalYear', 'Slicer', 'COVIDFILTER', 'DataSlicer', 'Location',
#        'Offenses', 'SelectSheet', 'StageFilter', 'AGE', 'AGE1', 'All',
#        'BasicRaceSexEthnicity', 'Category1', 'Circuit1', 'County',
#        'COVIDMONTHS', 'Date', 'EthnicGroup', 'Gender1', 'Offense1', 'Region',
#        'Stage', 'Stages1', 'Arrests', 'Arrestsper1000', 'Arrests/Youth',
#        'Arrests/Youth', 'Youth', 'Youthper1000', 'YouthPopulation',
#        'Youthpop'],
#       dtype='object')

# %%
girlsarst2020["EthnicGroup"].value_counts()
# Out:
# Black       5010
# White       3773
# Hispanic    1731
# Other         95
# Name: EthnicGroup, dtype: int64

# %%
girlsarst2020["County"].value_counts()
# Out:
# Orange          814
# Hillsborough    777
# Polk            752
# Pinellas        625
# Escambia        602
#                ...
# Dixie             6
# Franklin          6
# Glades            5
# Calhoun           5
# Liberty           4
# Name: County, Length: 68, dtype: int64

# %%
#Filtering dataset columns with only those columns which we would like to explore the data
df = girlsarst2020[
    [
        "Gender1",
        "AGE1",
        "EthnicGroup",
        "County",
        "Date",
        "Category1",
        "Offense1",
        "Region",
        "Stage",
        "Stages1",
    ]
]
df
# Out:
#       Gender1  AGE1 EthnicGroup     County       Date    Category1  \
# 0      Female  14.0       Black   Hamilton 2020-02-21       Felony
# 1      Female  17.0       Black   Hamilton 2020-01-06  Misdemeanor
# 2      Female  14.0       Black   Hamilton 2019-07-01        Other
# 3      Female  13.0       Black   Hamilton 2020-01-06  Misdemeanor
# 4      Female  15.0       Black   Hamilton 2020-01-23  Misdemeanor
# ...       ...   ...         ...        ...        ...          ...
# 10604  Female  15.0    Hispanic  Highlands 2020-04-27  Misdemeanor
# 10605  Female  16.0    Hispanic  Highlands 2019-12-10  Misdemeanor
# 10606  Female  11.0    Hispanic  Highlands 2019-10-23       Felony
# 10607  Female  11.0    Hispanic  Highlands 2020-02-28       Felony
# 10608  Female  16.0    Hispanic  Highlands 2019-11-21       Felony
#
#                               Offense1   Region    Stage Stages1
# 0                  Agg Assault/Battery    North  Arrests  Intake
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10609 entries, 0 to 10608
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender1      10609 non-null  object
#  1   AGE1         10539 non-null  float64
#  2   EthnicGroup  10609 non-null  object
#  3   County       10608 non-null  object
#  4   Date         10539 non-null  datetime64[ns]
#  5   Category1    10539 non-null  object
#  6   Offense1     10539 non-null  object
#  7   Region       10609 non-null  object
#  8   Stage        10539 non-null  object
#  9   Stages1      10609 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 829.0+ KB

# %%
# Check the mull rows first
df[df.isnull()]
# Out:
#       Gender1  AGE1 EthnicGroup County Date Category1 Offense1 Region Stage  \
# 0         NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 1         NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 2         NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 3         NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 4         NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# ...       ...   ...         ...    ...  ...       ...      ...    ...   ...
# 10604     NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 10605     NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 10606     NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 10607     NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
# 10608     NaN   NaN         NaN    NaN  NaT       NaN      NaN    NaN   NaN
#
#       Stages1
# 0         NaN
# 1         NaN
# ...

# %% [markdown]
# **Looks like all the rows having null values across all columns, so dropping them**

# %%
dfbk = df.copy()
df.dropna(inplace=True)
# Out:
# /Users/sumanghosh/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10539 entries, 0 to 10608
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender1      10539 non-null  object
#  1   AGE1         10539 non-null  float64
#  2   EthnicGroup  10539 non-null  object
#  3   County       10539 non-null  object
#  4   Date         10539 non-null  datetime64[ns]
#  5   Category1    10539 non-null  object
#  6   Offense1     10539 non-null  object
#  7   Region       10539 non-null  object
#  8   Stage        10539 non-null  object
#  9   Stages1      10539 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 905.7+ KB

# %%
df.isnull().sum()
# Out:
# Gender1        0
# AGE1           0
# EthnicGroup    0
# County         0
# Date           0
# Category1      0
# Offense1       0
# Region         0
# Stage          0
# Stages1        0
# dtype: int64

# %%
df["Offense_year"] = df["Date"].dt.year
df["Offense_month"] = df["Date"].dt.month
df["Offense_date"] = df["Date"].dt.day
# Out:
# /var/folders/sk/7ycgsnrn3c9b09dxcyqy5n800000gn/T/ipykernel_77706/3439397549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Offense_year"] = df["Date"].dt.year
# /var/folders/sk/7ycgsnrn3c9b09dxcyqy5n800000gn/T/ipykernel_77706/3439397549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Offense_month"] = df["Date"].dt.month
# /var/folders/sk/7ycgsnrn3c9b09dxcyqy5n800000gn/T/ipykernel_77706/3439397549.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       Gender1  AGE1 EthnicGroup     County       Date    Category1  \
# 0      Female  14.0       Black   Hamilton 2020-02-21       Felony
# 1      Female  17.0       Black   Hamilton 2020-01-06  Misdemeanor
# 2      Female  14.0       Black   Hamilton 2019-07-01        Other
# 3      Female  13.0       Black   Hamilton 2020-01-06  Misdemeanor
# 4      Female  15.0       Black   Hamilton 2020-01-23  Misdemeanor
# ...       ...   ...         ...        ...        ...          ...
# 10604  Female  15.0    Hispanic  Highlands 2020-04-27  Misdemeanor
# 10605  Female  16.0    Hispanic  Highlands 2019-12-10  Misdemeanor
# 10606  Female  11.0    Hispanic  Highlands 2019-10-23       Felony
# 10607  Female  11.0    Hispanic  Highlands 2020-02-28       Felony
# 10608  Female  16.0    Hispanic  Highlands 2019-11-21       Felony
#
#                               Offense1   Region    Stage Stages1  \
# 0                  Agg Assault/Battery    North  Arrests  Intake
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax = sns.countplot(
    df["EthnicGroup"],
    palette="winter_r",
    ax=ax,
    order=df["EthnicGroup"].value_counts().index,
)  # plotting first subplot
ax.set_title("Proportion of offenses by EthnicGroup")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# plt.xlabel(f"Brand Name (Total unique brands {ub})")
plt.ylabel("Count")
# perc_annot(ax1,dfused['brand_name']) #perc_annot() function is used to show the percentages annotation
tot = len(df["EthnicGroup"])
for p in ax.patches:
    percentage = "{:.1f}%".format(
        100 * p.get_height() / tot
    )  # percentage of each class of the category
    x = p.get_x() + p.get_width() / 3  # width of the plot
    y = p.get_y() + p.get_height() + 1  # hieght of the plot
    ax.annotate(percentage, (x, y), size=20)  # annotate the percantage

# %% [markdown]
# ### Observations:
#
# - Black has the highest proportions of offenses

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax = sns.countplot(df["Category1"], hue=df["EthnicGroup"], palette="winter_r")
tot = len(df["Category1"])
for p in ax.patches:
    percentage = "{:.1f}%".format(
        100 * p.get_height() / tot
    )  # percentage of each class of the category
    x = p.get_x() + p.get_width() / 5  # width of the plot
    y = p.get_y() + p.get_height() + 1  # hieght of the plot
    ax.annotate(percentage, (x, y), size=12)  # annotate the percantage

# %% [markdown]
# ### Observations:
#
# - Black has the highest proportions in all categories
# - Misdemeanor is the highest offense category. ~50%

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# ax = sns.countplot(df["County"], hue=df["Category1"], palette="winter_r", orient="v")
ax = sns.barplot(df["County"], df["AGE1"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Observations:
#
# - Almost all county age range of offense is same.
# - Madison county shows the lowest age as ~13 for offense

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.countplot(df["Offense1"], hue=df["EthnicGroup"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# #### Observations:
#
# - Assault/battery has the highest proportions in offense.
# - We can see Black and White both race are almost with same proportions for this offense.
# - Agg Assault is a big issue in Black, they are ~50% more than white.
